# %%
import chess.engine
import chess 
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import chess.pgn 
from stockfish import Stockfish
import pandas as pd
import time
import numpy as np
import chess
import chess.pgn
import time
import multiprocessing as mp
from stockfish import Stockfish
import numpy as np

# %%
from maia_functions import *

# %%
def extract_features(game):
    # Read the next game
    features = defaultdict(int)
    stockfish=Stockfish("../stockfish/stockfish-windows-x86-64-avx2.exe")
    stockfish.set_depth(15)#How deep the AI looks
    features = defaultdict(int)
    features["moves"] = [str(move) for move in game.mainline_moves()]
    features["WhiteElo"] = game.headers.get('WhiteElo', '')
    features["BlackElo"] = game.headers.get('BlackElo', '')
    features["white"] = game.headers.get('White', '')
    features["black"] = game.headers.get('Black', '')
    try:
        mm = maia_cpl(features, stockfish)
        features["maia_cpl_w"] = mm[0]
        features["maia_cpl_b"] = mm[1]
    except:
        return features
    return features

# %%
pgn_file_path = "../data/landing/fics_openings.pgn"

games = []
pgn_file = open(pgn_file_path)
game = chess.pgn.read_game(pgn_file)

start = 0
limit = 10000
count = 0
while game is not None:
    #features = extract_features(game)
    games.append(game)

    count += 1
    if count == limit:
        break
    game = chess.pgn.read_game(pgn_file)

pgn_file.close()

# %%
chunk_size = 1000  # Process 1000 games at a time
num_chunks = len(games) // chunk_size + (1 if len(games) % chunk_size > 0 else 0)
for i in range(4, num_chunks):
    result = []

    start_index = i * chunk_size
    end_index = min(start_index + chunk_size, len(games))
    games_chunk = games[start_index:end_index]

    for game in games_chunk:
        features = extract_features(game)
        result.append(features)

    ndjson_file_path = f'../data/raw/maia/fics_{start_index}.ndjson'
    print(f"saved to {ndjson_file_path}")
    print("--------------------------------------------------------")
    with open(ndjson_file_path, 'w') as f:
        for item in result:
            json.dump(item, f)
            f.write('\n')   
    break
# Out:
# <UciProtocol (pid=25628)>: stderr >>        _
# <UciProtocol (pid=25628)>: stderr >> |   _ | |
# <UciProtocol (pid=25628)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=25628)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=9240)>: stderr >>        _
# <UciProtocol (pid=9240)>: stderr >> |   _ | |
# <UciProtocol (pid=9240)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=9240)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=25628)>: stderr >> Loading weights file from: lc0_windows\models\maia-1200.pb.gz
# <UciProtocol (pid=25628)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=25628)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=25628)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=25628)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=25628)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=25628)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=25628)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=25628)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=25628)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1200.pb.gz
# --weights=lc0_windows\models\maia-1100.pb.gz
# <UciProtocol (pid=9240)>: stderr >> Loading weights file from: lc0_windows\models\maia-1100.pb.gz
# <UciProtocol (pid=9240)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=9240)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=9240)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=9240)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=9240)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=9240)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=9240)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=9240)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=9240)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=14432)>: stderr >>        _
# <UciProtocol (pid=14432)>: stderr >> |   _ | |
# <UciProtocol (pid=14432)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=14432)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=11772)>: stderr >>        _
# <UciProtocol (pid=11772)>: stderr >> |   _ | |
# <UciProtocol (pid=11772)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=11772)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=14432)>: stderr >> Loading weights file from: lc0_windows\models\maia-1800.pb.gz
# <UciProtocol (pid=14432)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=14432)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=14432)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=14432)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=14432)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=14432)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=14432)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=14432)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=14432)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1800.pb.gz
# --weights=lc0_windows\models\maia-1700.pb.gz
# <UciProtocol (pid=11772)>: stderr >> Loading weights file from: lc0_windows\models\maia-1700.pb.gz
# <UciProtocol (pid=11772)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=11772)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=11772)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=11772)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=11772)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=11772)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=11772)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=11772)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=11772)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=12340)>: stderr >>        _
# <UciProtocol (pid=12340)>: stderr >> |   _ | |
# <UciProtocol (pid=12340)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=12340)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=21608)>: stderr >>        _
# <UciProtocol (pid=21608)>: stderr >> |   _ | |
# <UciProtocol (pid=21608)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=21608)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=12340)>: stderr >> Loading weights file from: lc0_windows\models\maia-1300.pb.gz
# <UciProtocol (pid=12340)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=12340)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=12340)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=12340)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=12340)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=12340)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=12340)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=12340)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=12340)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1300.pb.gz
# --weights=lc0_windows\models\maia-1700.pb.gz
# <UciProtocol (pid=21608)>: stderr >> Loading weights file from: lc0_windows\models\maia-1700.pb.gz
# <UciProtocol (pid=21608)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=21608)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=21608)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=21608)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=21608)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=21608)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=21608)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=21608)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=21608)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=21644)>: stderr >>        _
# <UciProtocol (pid=21644)>: stderr >> |   _ | |
# <UciProtocol (pid=21644)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=21644)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=16644)>: stderr >>        _
# <UciProtocol (pid=16644)>: stderr >> |   _ | |
# <UciProtocol (pid=16644)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=16644)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=21644)>: stderr >> Loading weights file from: lc0_windows\models\maia-1600.pb.gz
# <UciProtocol (pid=21644)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=21644)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=21644)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=21644)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=21644)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=21644)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=21644)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=21644)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=21644)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1600.pb.gz
# --weights=lc0_windows\models\maia-1600.pb.gz
# <UciProtocol (pid=16644)>: stderr >> Loading weights file from: lc0_windows\models\maia-1600.pb.gz
# <UciProtocol (pid=16644)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=16644)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=16644)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=16644)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=16644)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=16644)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=16644)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=16644)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=16644)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=20896)>: stderr >>        _
# <UciProtocol (pid=20896)>: stderr >> |   _ | |
# <UciProtocol (pid=20896)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=20896)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=4976)>: stderr >>        _
# <UciProtocol (pid=4976)>: stderr >> |   _ | |
# <UciProtocol (pid=4976)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=4976)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=20896)>: stderr >> Loading weights file from: lc0_windows\models\maia-1600.pb.gz
# <UciProtocol (pid=20896)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=20896)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=20896)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=20896)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=20896)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=20896)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=20896)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=20896)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=20896)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1600.pb.gz
# --weights=lc0_windows\models\maia-1500.pb.gz
# <UciProtocol (pid=4976)>: stderr >> Loading weights file from: lc0_windows\models\maia-1500.pb.gz
# <UciProtocol (pid=4976)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=4976)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=4976)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=4976)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=4976)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=4976)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=4976)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=4976)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=4976)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=18696)>: stderr >>        _
# <UciProtocol (pid=18696)>: stderr >> |   _ | |
# <UciProtocol (pid=18696)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=18696)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=23356)>: stderr >>        _
# <UciProtocol (pid=23356)>: stderr >> |   _ | |
# <UciProtocol (pid=23356)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=23356)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=18696)>: stderr >> Loading weights file from: lc0_windows\models\maia-1700.pb.gz
# <UciProtocol (pid=18696)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=18696)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=18696)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=18696)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=18696)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=18696)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=18696)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=18696)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=18696)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1700.pb.gz
# --weights=lc0_windows\models\maia-1800.pb.gz
# <UciProtocol (pid=23356)>: stderr >> Loading weights file from: lc0_windows\models\maia-1800.pb.gz
# <UciProtocol (pid=23356)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=23356)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=23356)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=23356)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=23356)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=23356)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=23356)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=23356)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=23356)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=19224)>: stderr >>        _
# <UciProtocol (pid=19224)>: stderr >> |   _ | |
# <UciProtocol (pid=19224)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=19224)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=9940)>: stderr >>        _
# <UciProtocol (pid=9940)>: stderr >> |   _ | |
# <UciProtocol (pid=9940)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=9940)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=19224)>: stderr >> Loading weights file from: lc0_windows\models\maia-1400.pb.gz
# <UciProtocol (pid=19224)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=19224)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=19224)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=19224)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=19224)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=19224)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=19224)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=19224)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=19224)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1400.pb.gz
# --weights=lc0_windows\models\maia-1500.pb.gz
# <UciProtocol (pid=9940)>: stderr >> Loading weights file from: lc0_windows\models\maia-1500.pb.gz
# <UciProtocol (pid=9940)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=9940)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=9940)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=9940)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=9940)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=9940)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=9940)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=9940)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=9940)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=19780)>: stderr >>        _
# <UciProtocol (pid=19780)>: stderr >> |   _ | |
# <UciProtocol (pid=19780)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=19780)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=25264)>: stderr >>        _
# <UciProtocol (pid=25264)>: stderr >> |   _ | |
# <UciProtocol (pid=25264)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=25264)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=19780)>: stderr >> Loading weights file from: lc0_windows\models\maia-1400.pb.gz
# <UciProtocol (pid=19780)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=19780)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=19780)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=19780)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=19780)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=19780)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=19780)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=19780)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=19780)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1400.pb.gz
# --weights=lc0_windows\models\maia-1400.pb.gz
# <UciProtocol (pid=25264)>: stderr >> Loading weights file from: lc0_windows\models\maia-1400.pb.gz
# <UciProtocol (pid=25264)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=25264)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=25264)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=25264)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=25264)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=25264)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=25264)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=25264)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=25264)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=6528)>: stderr >>        _
# <UciProtocol (pid=6528)>: stderr >> |   _ | |
# <UciProtocol (pid=6528)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=6528)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=4692)>: stderr >>        _
# <UciProtocol (pid=4692)>: stderr >> |   _ | |
# <UciProtocol (pid=4692)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=4692)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=6528)>: stderr >> Loading weights file from: lc0_windows\models\maia-1100.pb.gz
# <UciProtocol (pid=6528)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=6528)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=6528)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=6528)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=6528)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=6528)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=6528)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=6528)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=6528)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1100.pb.gz
# --weights=lc0_windows\models\maia-1300.pb.gz
# <UciProtocol (pid=4692)>: stderr >> Loading weights file from: lc0_windows\models\maia-1300.pb.gz
# <UciProtocol (pid=4692)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=4692)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=4692)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=4692)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=4692)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=4692)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=4692)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=4692)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=4692)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=5992)>: stderr >>        _
# <UciProtocol (pid=5992)>: stderr >> |   _ | |
# <UciProtocol (pid=5992)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=5992)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=21304)>: stderr >>        _
# <UciProtocol (pid=21304)>: stderr >> |   _ | |
# <UciProtocol (pid=21304)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=21304)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=5992)>: stderr >> Loading weights file from: lc0_windows\models\maia-1100.pb.gz
# <UciProtocol (pid=5992)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=5992)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=5992)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=5992)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=5992)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=5992)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=5992)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=5992)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=5992)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1100.pb.gz
# --weights=lc0_windows\models\maia-1200.pb.gz
# <UciProtocol (pid=21304)>: stderr >> Loading weights file from: lc0_windows\models\maia-1200.pb.gz
# <UciProtocol (pid=21304)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=21304)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=21304)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=21304)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=21304)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=21304)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=21304)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=21304)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=21304)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=26144)>: stderr >>        _
# <UciProtocol (pid=26144)>: stderr >> |   _ | |
# <UciProtocol (pid=26144)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=26144)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=4672)>: stderr >>        _
# <UciProtocol (pid=4672)>: stderr >> |   _ | |
# <UciProtocol (pid=4672)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=4672)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=26144)>: stderr >> Loading weights file from: lc0_windows\models\maia-1800.pb.gz
# <UciProtocol (pid=26144)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=26144)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=26144)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=26144)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=26144)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=26144)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=26144)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=26144)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=26144)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1800.pb.gz
# --weights=lc0_windows\models\maia-1800.pb.gz
# <UciProtocol (pid=4672)>: stderr >> Loading weights file from: lc0_windows\models\maia-1800.pb.gz
# <UciProtocol (pid=4672)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=4672)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=4672)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=4672)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=4672)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=4672)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=4672)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=4672)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=4672)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=16916)>: stderr >>        _
# <UciProtocol (pid=16916)>: stderr >> |   _ | |
# <UciProtocol (pid=16916)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=16916)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=21728)>: stderr >>        _
# <UciProtocol (pid=21728)>: stderr >> |   _ | |
# <UciProtocol (pid=21728)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=21728)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=16916)>: stderr >> Loading weights file from: lc0_windows\models\maia-1400.pb.gz
# <UciProtocol (pid=16916)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=16916)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=16916)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=16916)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=16916)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=16916)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=16916)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=16916)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=16916)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1400.pb.gz
# --weights=lc0_windows\models\maia-1400.pb.gz
# <UciProtocol (pid=21728)>: stderr >> Loading weights file from: lc0_windows\models\maia-1400.pb.gz
# <UciProtocol (pid=21728)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=21728)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=21728)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=21728)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=21728)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=21728)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=21728)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=21728)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=21728)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=7680)>: stderr >>        _
# <UciProtocol (pid=7680)>: stderr >> |   _ | |
# <UciProtocol (pid=7680)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=7680)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=13596)>: stderr >>        _
# <UciProtocol (pid=13596)>: stderr >> |   _ | |
# <UciProtocol (pid=13596)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=13596)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=7680)>: stderr >> Loading weights file from: lc0_windows\models\maia-1500.pb.gz
# <UciProtocol (pid=7680)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=7680)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=7680)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=7680)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=7680)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=7680)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=7680)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=7680)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=7680)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1500.pb.gz
# --weights=lc0_windows\models\maia-1500.pb.gz
# <UciProtocol (pid=13596)>: stderr >> Loading weights file from: lc0_windows\models\maia-1500.pb.gz
# <UciProtocol (pid=13596)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=13596)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=13596)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=13596)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=13596)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=13596)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=13596)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=13596)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=13596)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=4440)>: stderr >>        _
# <UciProtocol (pid=4440)>: stderr >> |   _ | |
# <UciProtocol (pid=4440)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=4440)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=16792)>: stderr >>        _
# <UciProtocol (pid=16792)>: stderr >> |   _ | |
# <UciProtocol (pid=16792)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=16792)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=4440)>: stderr >> Loading weights file from: lc0_windows\models\maia-1500.pb.gz
# <UciProtocol (pid=4440)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=4440)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=4440)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=4440)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=4440)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=4440)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=4440)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=4440)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=4440)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1500.pb.gz
# --weights=lc0_windows\models\maia-1500.pb.gz
# <UciProtocol (pid=16792)>: stderr >> Loading weights file from: lc0_windows\models\maia-1500.pb.gz
# <UciProtocol (pid=16792)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=16792)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=16792)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=16792)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=16792)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=16792)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=16792)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=16792)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=16792)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=21528)>: stderr >>        _
# <UciProtocol (pid=21528)>: stderr >> |   _ | |
# <UciProtocol (pid=21528)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=21528)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=23952)>: stderr >>        _
# <UciProtocol (pid=23952)>: stderr >> |   _ | |
# <UciProtocol (pid=23952)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=23952)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=21528)>: stderr >> Loading weights file from: lc0_windows\models\maia-1100.pb.gz
# <UciProtocol (pid=21528)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=21528)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=21528)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=21528)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=21528)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=21528)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=21528)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=21528)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=21528)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1100.pb.gz
# --weights=lc0_windows\models\maia-1100.pb.gz
# <UciProtocol (pid=23952)>: stderr >> Loading weights file from: lc0_windows\models\maia-1100.pb.gz
# <UciProtocol (pid=23952)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=23952)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=23952)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=23952)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=23952)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=23952)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=23952)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=23952)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=23952)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=7904)>: stderr >>        _
# <UciProtocol (pid=7904)>: stderr >> |   _ | |
# <UciProtocol (pid=7904)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=7904)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=23844)>: stderr >>        _
# <UciProtocol (pid=23844)>: stderr >> |   _ | |
# <UciProtocol (pid=23844)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=23844)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=7904)>: stderr >> Loading weights file from: lc0_windows\models\maia-1300.pb.gz
# <UciProtocol (pid=7904)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=7904)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=7904)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=7904)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=7904)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=7904)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=7904)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=7904)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=7904)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1300.pb.gz
# --weights=lc0_windows\models\maia-1300.pb.gz
# <UciProtocol (pid=23844)>: stderr >> Loading weights file from: lc0_windows\models\maia-1300.pb.gz
# <UciProtocol (pid=23844)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=23844)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=23844)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=23844)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=23844)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=23844)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=23844)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=23844)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=23844)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=14372)>: stderr >>        _
# <UciProtocol (pid=14372)>: stderr >> |   _ | |
# <UciProtocol (pid=14372)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=14372)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=16876)>: stderr >>        _
# <UciProtocol (pid=16876)>: stderr >> |   _ | |
# <UciProtocol (pid=16876)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=16876)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=14372)>: stderr >> Loading weights file from: lc0_windows\models\maia-1400.pb.gz
# <UciProtocol (pid=14372)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=14372)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=14372)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=14372)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=14372)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=14372)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=14372)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=14372)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=14372)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1400.pb.gz
# --weights=lc0_windows\models\maia-1500.pb.gz
# <UciProtocol (pid=16876)>: stderr >> Loading weights file from: lc0_windows\models\maia-1500.pb.gz
# <UciProtocol (pid=16876)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=16876)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=16876)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=16876)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=16876)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=16876)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=16876)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=16876)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=16876)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=13704)>: stderr >>        _
# <UciProtocol (pid=13704)>: stderr >> |   _ | |
# <UciProtocol (pid=13704)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=13704)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=23856)>: stderr >>        _
# <UciProtocol (pid=23856)>: stderr >> |   _ | |
# <UciProtocol (pid=23856)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=23856)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=13704)>: stderr >> Loading weights file from: lc0_windows\models\maia-1900.pb.gz
# <UciProtocol (pid=13704)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=13704)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=13704)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=13704)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=13704)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=13704)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=13704)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=13704)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=13704)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1900.pb.gz
# --weights=lc0_windows\models\maia-1400.pb.gz
# <UciProtocol (pid=23856)>: stderr >> Loading weights file from: lc0_windows\models\maia-1400.pb.gz
# <UciProtocol (pid=23856)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=23856)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=23856)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=23856)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=23856)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=23856)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=23856)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=23856)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=23856)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=11908)>: stderr >>        _
# <UciProtocol (pid=11908)>: stderr >> |   _ | |
# <UciProtocol (pid=11908)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=11908)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=23408)>: stderr >>        _
# <UciProtocol (pid=23408)>: stderr >> |   _ | |
# <UciProtocol (pid=23408)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=23408)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=11908)>: stderr >> Loading weights file from: lc0_windows\models\maia-1900.pb.gz
# <UciProtocol (pid=11908)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=11908)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=11908)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=11908)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=11908)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=11908)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=11908)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=11908)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=11908)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1900.pb.gz
# --weights=lc0_windows\models\maia-1900.pb.gz
# <UciProtocol (pid=23408)>: stderr >> Loading weights file from: lc0_windows\models\maia-1900.pb.gz
# <UciProtocol (pid=23408)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=23408)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=23408)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=23408)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=23408)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=23408)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=23408)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=23408)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=23408)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=24652)>: stderr >>        _
# <UciProtocol (pid=24652)>: stderr >> |   _ | |
# <UciProtocol (pid=24652)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=24652)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=12188)>: stderr >>        _
# <UciProtocol (pid=12188)>: stderr >> |   _ | |
# <UciProtocol (pid=12188)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=12188)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=24652)>: stderr >> Loading weights file from: lc0_windows\models\maia-1500.pb.gz
# <UciProtocol (pid=24652)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=24652)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=24652)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=24652)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=24652)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=24652)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=24652)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=24652)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=24652)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1500.pb.gz
# --weights=lc0_windows\models\maia-1600.pb.gz
# <UciProtocol (pid=12188)>: stderr >> Loading weights file from: lc0_windows\models\maia-1600.pb.gz
# <UciProtocol (pid=12188)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=12188)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=12188)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=12188)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=12188)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=12188)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=12188)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=12188)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=12188)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=8140)>: stderr >>        _
# <UciProtocol (pid=8140)>: stderr >> |   _ | |
# <UciProtocol (pid=8140)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=8140)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=6884)>: stderr >>        _
# <UciProtocol (pid=6884)>: stderr >> |   _ | |
# <UciProtocol (pid=6884)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=6884)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=8140)>: stderr >> Loading weights file from: lc0_windows\models\maia-1700.pb.gz
# <UciProtocol (pid=8140)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=8140)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=8140)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=8140)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=8140)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=8140)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=8140)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=8140)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=8140)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1700.pb.gz
# --weights=lc0_windows\models\maia-1400.pb.gz
# <UciProtocol (pid=6884)>: stderr >> Loading weights file from: lc0_windows\models\maia-1400.pb.gz
# <UciProtocol (pid=6884)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=6884)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=6884)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=6884)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=6884)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=6884)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=6884)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=6884)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=6884)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=15896)>: stderr >>        _
# <UciProtocol (pid=15896)>: stderr >> |   _ | |
# <UciProtocol (pid=15896)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=15896)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=7100)>: stderr >>        _
# <UciProtocol (pid=7100)>: stderr >> |   _ | |
# <UciProtocol (pid=7100)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=7100)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=15896)>: stderr >> Loading weights file from: lc0_windows\models\maia-1400.pb.gz
# <UciProtocol (pid=15896)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=15896)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=15896)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=15896)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=15896)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=15896)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=15896)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=15896)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=15896)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1400.pb.gz
# --weights=lc0_windows\models\maia-1100.pb.gz
# <UciProtocol (pid=7100)>: stderr >> Loading weights file from: lc0_windows\models\maia-1100.pb.gz
# <UciProtocol (pid=7100)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=7100)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=7100)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=7100)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=7100)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=7100)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=7100)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=7100)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=7100)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=14980)>: stderr >>        _
# <UciProtocol (pid=14980)>: stderr >> |   _ | |
# <UciProtocol (pid=14980)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=14980)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=15980)>: stderr >>        _
# <UciProtocol (pid=15980)>: stderr >> |   _ | |
# <UciProtocol (pid=15980)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=15980)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=14980)>: stderr >> Loading weights file from: lc0_windows\models\maia-1300.pb.gz
# <UciProtocol (pid=14980)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=14980)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=14980)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=14980)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=14980)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=14980)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=14980)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=14980)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=14980)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1300.pb.gz
# --weights=lc0_windows\models\maia-1100.pb.gz
# <UciProtocol (pid=15980)>: stderr >> Loading weights file from: lc0_windows\models\maia-1100.pb.gz
# <UciProtocol (pid=15980)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=15980)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=15980)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=15980)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=15980)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=15980)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=15980)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=15980)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=15980)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=22076)>: stderr >>        _
# ...
# <UciProtocol (pid=15080)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=15080)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=16240)>: stderr >>        _
# <UciProtocol (pid=16240)>: stderr >> |   _ | |
# <UciProtocol (pid=16240)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=16240)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=15080)>: stderr >> Loading weights file from: lc0_windows\models\maia-1100.pb.gz
# <UciProtocol (pid=15080)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=15080)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=15080)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=15080)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=15080)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=15080)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=15080)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=15080)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=15080)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1100.pb.gz
# --weights=lc0_windows\models\maia-1100.pb.gz
# <UciProtocol (pid=16240)>: stderr >> Loading weights file from: lc0_windows\models\maia-1100.pb.gz
# <UciProtocol (pid=16240)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=16240)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=16240)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=16240)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=16240)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=16240)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=16240)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=16240)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=16240)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=12152)>: stderr >>        _
# <UciProtocol (pid=12152)>: stderr >> |   _ | |
# <UciProtocol (pid=12152)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=12152)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=19952)>: stderr >>        _
# <UciProtocol (pid=19952)>: stderr >> |   _ | |
# <UciProtocol (pid=19952)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=19952)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=12152)>: stderr >> Loading weights file from: lc0_windows\models\maia-1600.pb.gz
# <UciProtocol (pid=12152)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=12152)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=12152)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=12152)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=12152)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=12152)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=12152)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=12152)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=12152)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1600.pb.gz
# --weights=lc0_windows\models\maia-1500.pb.gz
# <UciProtocol (pid=19952)>: stderr >> Loading weights file from: lc0_windows\models\maia-1500.pb.gz
# <UciProtocol (pid=19952)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=19952)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=19952)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=19952)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=19952)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=19952)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=19952)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=19952)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=19952)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=18564)>: stderr >>        _
# <UciProtocol (pid=18564)>: stderr >> |   _ | |
# <UciProtocol (pid=18564)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=18564)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=2332)>: stderr >>        _
# <UciProtocol (pid=2332)>: stderr >> |   _ | |
# <UciProtocol (pid=2332)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=2332)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=18564)>: stderr >> Loading weights file from: lc0_windows\models\maia-1600.pb.gz
# <UciProtocol (pid=18564)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=18564)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=18564)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=18564)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=18564)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=18564)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=18564)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=18564)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=18564)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1600.pb.gz
# --weights=lc0_windows\models\maia-1700.pb.gz
# <UciProtocol (pid=2332)>: stderr >> Loading weights file from: lc0_windows\models\maia-1700.pb.gz
# <UciProtocol (pid=2332)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=2332)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=2332)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=2332)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=2332)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=2332)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=2332)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=2332)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=2332)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=2332)>: Unexpected engine output: 'error CUDA error: out of memory (c:\\projects\\lc0\\src\\neural\\cuda\\network_cuda.cc:588) '
# <UciProtocol (pid=2332)>: stderr >> Loading weights file from: lc0_windows\models\maia-1700.pb.gz
# <UciProtocol (pid=2332)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=2332)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=2332)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=2332)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=2332)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=2332)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=2332)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=2332)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=2332)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=2332)>: Unexpected engine output: 'error CUDA error: out of memory (c:\\projects\\lc0\\src\\neural\\cuda\\network_cuda.cc:369) '
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# e7e6
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# d2d4
# UciPlayCommand failed after returning preliminary result (<Future cancelled>)
# protocol: <UciProtocol (pid=2332)>
# transport: <_WindowsSubprocessTransport pid=2332 returncode=0 stdin=<_ProactorWritePipeTransport closed> stdout=<_ProactorReadPipeTransport closed> stderr=<_ProactorReadPipeTransport closed>>
# chess.engine.EngineTerminatedError: engine process died unexpectedly (exit code: 0)
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# f8e7
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# c1e3
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# d6d5
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# e4d5
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# e6d5
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# c2c3
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# g8f6
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# b1d2
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# e8g8
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# e1g1
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# f8e8
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# e3f2
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# e7d6
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# f3e5
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# g4e2
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# d1e2
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# f6d7
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# e2g4
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# f7f6
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# e5d7
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# h7h5
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# g4h3
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# d6f4
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# d2b3
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# b7b6
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# h3f5
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# f4h6
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# f5d5
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# g8h8
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# d5c6
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# e8e2
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# a1e1
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# e2b2
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# e1e7
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# b2a2
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# d7f6
# error: black move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# d8e7
# error: white move
# r . . q k b n r
# p p p . p p p p
# . . n p . . . .
# . . . . . . . .
# . . . . P P b .
# . . . . . N . .
# P P P P B . P P
# R N B Q K . . R
# c6a8
# <UciProtocol (pid=20636)>: stderr >>        _
# <UciProtocol (pid=20636)>: stderr >> |   _ | |
# <UciProtocol (pid=20636)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=20636)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=12684)>: stderr >>        _
# <UciProtocol (pid=12684)>: stderr >> |   _ | |
# <UciProtocol (pid=12684)>: stderr >> |_ |_ |_| v0.31.1 built Aug 11 2024
# <UciProtocol (pid=12684)>: stderr >> Found configuration file: c:\pc_coding\Finding-Elo\maia.chess\lc0_windows/lc0.config
# <UciProtocol (pid=20636)>: stderr >> Loading weights file from: lc0_windows\models\maia-1100.pb.gz
# <UciProtocol (pid=20636)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=20636)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=20636)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=20636)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=20636)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=20636)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=20636)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=20636)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=20636)>: stderr >> L2 cache capacity: 4194304
# --weights=lc0_windows\models\maia-1100.pb.gz
# --weights=lc0_windows\models\maia-1200.pb.gz
# <UciProtocol (pid=20636)>: Unexpected engine output: 'error CUDA error: out of memory (c:\\projects\\lc0\\src\\neural\\cuda\\network_cuda.cc:588) '
# <UciProtocol (pid=20636)>: stderr >> Loading weights file from: lc0_windows\models\maia-1100.pb.gz
# <UciProtocol (pid=20636)>: stderr >> Creating backend [cuda-auto]...
# <UciProtocol (pid=20636)>: stderr >> Switching to [cuda-fp16]...
# <UciProtocol (pid=20636)>: stderr >> CUDA Runtime version: 11.1.0
# <UciProtocol (pid=20636)>: stderr >> Latest version of CUDA supported by the driver: 12.6.0
# <UciProtocol (pid=20636)>: stderr >> GPU: NVIDIA GeForce RTX 3070
# <UciProtocol (pid=20636)>: stderr >> GPU memory: 7.99951 Gb
# <UciProtocol (pid=20636)>: stderr >> GPU clock frequency: 1815 MHz
# <UciProtocol (pid=20636)>: stderr >> GPU compute capability: 8.6
# <UciProtocol (pid=20636)>: stderr >> L2 cache capacity: 4194304
# <UciProtocol (pid=20636)>: Unexpected engine output: 'error CUDA error: out of memory (c:\\projects\\lc0\\src\\neural\\cuda\\network_cuda.cc:369) '
